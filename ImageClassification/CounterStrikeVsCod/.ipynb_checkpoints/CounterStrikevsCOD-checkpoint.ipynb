# %%
from fastai.vision import *
from fastai.widgets import *

# %% [markdown]
# # Image classifier DNN (Counter Stirke vs Call Of Duty)

# %% [markdown]
# Downloading data

# %%
path = Path('/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/data')
path_cs = path/'cs'
path_cod = path/'cod'

# %%
path_cs.mkdir(parents = True, exist_ok = True)
path_cod.mkdir(parents = True, exist_ok = True)

# %%
download_images(path/'cod.txt', path_cod)
download_images(path/'cs.txt', path_cs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:42<00:00]
#     </div>
# Error https://i0.wp.com/evilsourcegaming.com/wp-content/uploads/2015/06/Black_Ops_3_Evac_Beware_of_Blast_WM_50.jpg HTTPSConnectionPool(host='i0.wp.com', port=443): Read timed out. (read timeout=4)
# Error https://i0.wp.com/evilsourcegaming.com/wp-content/uploads/2015/06/Black_Ops_3_Evac_Beware_of_Blast_WM_50.jpg HTTPSConnectionPool(host='i0.wp.com', port=443): Read timed out. (read timeout=4)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:33<00:00]
#     </div>
# Error http://static2.iphonecake.com/appcake/appimg2/1203/505522871-2.jpg HTTPConnectionPool(host='static2.iphonecake.com', port=80): Max retries exceeded with url: /appcake/appimg2/1203/505522871-2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f85a8ce0390>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error https://gamers-underground.com/filedata/fetch?id=644191 HTTPSConnectionPool(host='gamers-underground.com', port=443): Read timed out. (read timeout=4)
# Error https://gamefabrique.com/storage/screenshots/pc/counter-strike-02.png HTTPSConnectionPool(host='gamefabrique.com', port=443): Max retries exceeded with url: /storage/screenshots/pc/counter-strike-02.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://games4win.com/up/counter-strike-01.png HTTPSConnectionPool(host='games4win.com', port=443): Max retries exceeded with url: /up/counter-strike-01.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://static2.cs-bg.net/maps/images/screenshots/mapssource/awp/css-1816-awp_india_v2.jpg HTTPSConnectionPool(host='static2.cs-bg.net', port=443): Max retries exceeded with url: /maps/images/screenshots/mapssource/awp/css-1816-awp_india_v2.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://www.mods-apk.com/en/wp-content/uploads/2018/09/Critical-Strike-CS-Counter-Terrorist-Online-FPS-5.1-screenshots-8.jpg HTTPSConnectionPool(host='www.mods-apk.com', port=443): Read timed out. (read timeout=4)
# Error https://static2.cs-bg.net/maps/images/screenshots/maps16/fy/cs-3435-fy_out.jpg HTTPSConnectionPool(host='static2.cs-bg.net', port=443): Max retries exceeded with url: /maps/images/screenshots/maps16/fy/cs-3435-fy_out.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://static2.cs-bg.net/maps/images/screenshots/maps16/aim/cs-2976-aim_map_2010.jpg HTTPSConnectionPool(host='static2.cs-bg.net', port=443): Max retries exceeded with url: /maps/images/screenshots/maps16/aim/cs-2976-aim_map_2010.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://static2.cs-bg.net/maps/images/screenshots/maps16/fy/cs-2986-fy_tuscan.jpg HTTPSConnectionPool(host='static2.cs-bg.net', port=443): Max retries exceeded with url: /maps/images/screenshots/maps16/fy/cs-2986-fy_tuscan.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://static2.cs-bg.net/maps/images/screenshots/maps16/fy/cs-2526-fy_buzzkill.jpg HTTPSConnectionPool(host='static2.cs-bg.net', port=443): Max retries exceeded with url: /maps/images/screenshots/maps16/fy/cs-2526-fy_buzzkill.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://is5-ssl.mzstatic.com/image/thumb/Purple125/v4/4d/bc/2d/4dbc2da6-b5cf-bcca-090e-b024a84ce1a0/pr_source.png/643x0w.jpg HTTPSConnectionPool(host='is5-ssl.mzstatic.com', port=443): Read timed out. (read timeout=4)
# Error https://static2.cs-bg.net/maps/images/screenshots/maps16/fy/cs-2984-fy_winter2.jpg HTTPSConnectionPool(host='static2.cs-bg.net', port=443): Max retries exceeded with url: /maps/images/screenshots/maps16/fy/cs-2984-fy_winter2.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))

# %%
verify_images(path_cod, delete = True)
verify_images(path_cs, delete = True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='394' class='' max='394', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [394/394 00:05<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000102.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000064.png has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000317.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000347.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000361.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000049.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000022.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000262.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000291.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000041.png has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000334.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000304.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000174.png has 1 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000053.png has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cod/00000224.png has 1 instead of 3 channels
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='386' class='' max='386', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [386/386 00:02<00:00]
#     </div>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000102.jpg has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000308.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000246.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000315.jpeg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000382.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000181.jpg has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000349.png has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000045.jpg has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000163.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000348.png has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000123.PNG has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000289.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000398.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000039.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000218.jpg has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000158.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000203.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000337.png has 4 instead of 3 channels
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000313.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000121.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000365.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000359.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000287.jpg has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000309.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000144.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000057.jpg'>
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000340.jpg'>
# Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000379.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000024.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000068.jpg'>
# Image /home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000388.png has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='/home/louis/Documents/github/FastAIDLproj/ImageClassification/CounterStrikeVsCod/cs/00000263.jpg'>

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train = ".", valid_pct = 0.2, ds_tfms = get_transforms(), size = 224, num_workers = 4).normalize(imagenet_stats)

# %%
data.show_batch(rows = 3)

# %%
learn = create_cnn(data, models.resnet34, metrics = error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:56 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.399790</th>
#     <th>0.284136</th>
#     <th>0.075342</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.348083</th>
#     <th>0.270169</th>
#     <th>0.102740</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.326716</th>
#     <th>0.262656</th>
#     <th>0.102740</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.291398</th>
#     <th>0.262465</th>
#     <th>0.109589</th>
#   </tr>
# </table>

# %%
learn.save('v01')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(20)

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:55 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.203202</th>
#     <th>0.252855</th>
#     <th>0.095890</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.192557</th>
#     <th>0.226980</th>
#     <th>0.095890</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.188852</th>
#     <th>0.215752</th>
#     <th>0.089041</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.176942</th>
#     <th>0.211530</th>
#     <th>0.089041</th>
#   </tr>
# </table>

# %%
learn.unfreeze()

# %%
doc(learn.unfreeze)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr = slice(1e-6,1e-4))
# Out:
# Total time: 00:26 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.168573</th>
#     <th>0.210003</th>
#     <th>0.089041</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.156601</th>
#     <th>0.211486</th>
#     <th>0.089041</th>
#   </tr>
# </table>
